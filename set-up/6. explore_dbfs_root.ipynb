# %% [markdown]
# # Explore DBFS Root
# - List all folders in dbfs root
# - Interact with DBFS file browser ( enable thru admin first)
# - Uplaod file to DBFS root

# %%
display(dbutils.fs.ls('/'))

# %%
display(dbutils.fs.ls('/FileStore'))

# %%
display(spark.read.csv('/FileStore/circuits.csv'))
