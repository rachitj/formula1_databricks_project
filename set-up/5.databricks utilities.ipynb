# %% [markdown]
# # Databricks Utilities

# %%
dbutils.secrets.help()

# %%
dbutils.secrets.listScopes()

# %%
dbutils.secrets.get(scope = 'formula1-scope', key = 'formula1dlrj-account-key')

# %%
dbutils.fs.help('ls')
